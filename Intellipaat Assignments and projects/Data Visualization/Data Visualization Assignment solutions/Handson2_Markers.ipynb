# %%
import matplotlib.pyplot as plt

# %%
#Run the following code to create a plot with markers that look like the addition symbol

plt.plot([x for x in range(0,10)],marker="P")

# %%
#Run the following code to create a plot with markers that look like the diamond symbol

plt.plot([x for x in range(0,10)],marker="D")
