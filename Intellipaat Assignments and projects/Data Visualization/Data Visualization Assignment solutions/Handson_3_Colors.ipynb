# %%
import matplotlib.pyplot as plt

# %%
#Run the following code to create a plot with two lines with different colors.

plt.plot([x*x for x in range(0,10)],color="red",marker="P")
plt.plot([x*x for x in range(9,-1,-1)],color="blue",marker="P")
